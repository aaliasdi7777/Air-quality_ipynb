# %% [markdown]
# <a href="https://colab.research.google.com/github/aaliasdi7777/Air-quality_ipynb/blob/main/scratchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
# !gdown --id 1fW5NuOAy3qEPFa8MFSzeUYaqaEGrLIXY #leo's photo
# !gdown --id 1l058oXzyYMXlo9CAgMD-56bGfzGpiwtJ #font
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1fW5NuOAy3qEPFa8MFSzeUYaqaEGrLIXY
# To: /content/leonardo-dicaprio.jpg
# 100% 781k/781k [00:00<00:00, 95.2MB/s]
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1l058oXzyYMXlo9CAgMD-56bGfzGpiwtJ
# To: /content/arial.ttf
# 100% 312k/312k [00:00<00:00, 91.8MB/s]

# %%
im = Image.open("leonardo-dicaprio.jpg")

# %%
im.format #extension
# Out:
# 'JPEG'

# %%
im.size #height * width
# Out:
# (1501, 844)

# %%
im.mode
# Out:
# 'RGB'

# %%
from PIL import ImageOps
gray_image = ImageOps.grayscale(im)

# %%
gray_image.mode
# Out:
# 'L'

# %%
plt.imshow(gray_image)

# %%
im.show()

# %%
plt.imshow(im)

# %%
im.save("new_image.jpg")

# %%
im_copy = im.copy()

# %%
plt.imshow(im_copy)

# %%
left = 50
top = 100
right = 400
bottom = 400
cropped = im.crop((left, top, right, bottom))
plt.imshow(cropped)

# %%
im_transposed_01 = im.transpose(Image.ROTATE_180)
im_transposed_02 = im.transpose(Image.FLIP_LEFT_RIGHT)
im_transposed_03 = im.transpose(Image.FLIP_TOP_BOTTOM)
im_transposed_04 = im.transpose(Image.ROTATE_180)
im_transposed_05 = im.transpose(Image.ROTATE_180)
im_transposed_06 = im.transpose(Image.ROTATE_270)

plt.subplot(321)
plt.imshow(im_transposed_01)

plt.subplot(322)
plt.imshow(im_transposed_02)

plt.subplot(323)
plt.imshow(im_transposed_03)

plt.subplot(324)
plt.imshow(im_transposed_04)

plt.subplot(325)
plt.imshow(im_transposed_05)

plt.subplot(326)
plt.imshow(im_transposed_06)

# %%
new_size = (50, 50)
out = im.resize(new_size)
plt.imshow(out)
